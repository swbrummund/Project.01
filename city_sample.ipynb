# %%
import pandas as pd
import numpy as np

output_data_file = "Data_Collection/Census_API/CensusDataFrame.csv"
output_loc = "Data_Collection/Census_API/sample.csv"
census_df = pd.read_csv(output_data_file)
census_df
# Out:
#      Unnamed: 0           County        State  Population  Median Age  \
# 0           777    Dubois County      Indiana     42345.0        40.9
# 1          1729  Cheyenne County     Nebraska     10090.0        40.5
# 2          1194  Pemiscot County     Missouri     17599.0        37.8
# 3          2080    Holmes County         Ohio     43702.0        30.6
# 4          2751  Mitchell County        Texas      8995.0        35.5
# ..          ...              ...          ...         ...         ...
# 595          35    Lonoke County     Arkansas     71279.0        35.8
# 596        1077     Casey County     Kentucky     15928.0        42.6
# 597        1441      Rice County    Minnesota     65116.0        36.5
# 598         268    Gilpin County     Colorado      5708.0        44.8
# 599        1837  Cape May County   New Jersey     95404.0        48.4
#
#      Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0             55154.0            27331.0         3545.0      8.371709
# 1             54215.0            30929.0          996.0      9.871160
# 2             31671.0            17681.0         5036.0     28.615262
# 3             53619.0            19517.0         5504.0     12.594389
# 4             51555.0            19334.0          654.0      7.270706
# ..                ...                ...            ...           ...
# 595           56156.0            24501.0         8535.0     11.974074
# 596           32315.0            18146.0         4114.0     25.828729
# 597           61683.0            27856.0         6678.0     10.255544
# 598           67544.0            37027.0          392.0      6.867554
# 599           59338.0            34550.0         9695.0     10.162048
#
#      Unemployed Citizens
# 0                  649.0
# 1                  136.0
# 2                  809.0
# 3                  688.0
# 4                  193.0
# ..                   ...
# 595               1932.0
# 596                601.0
# 597               1548.0
# 598                128.0
# 599               4357.0
#
# [600 rows x 10 columns]

# %%
samplecensus_df = census_df.sample(n=600)
samplecensus_df.to_csv(output_loc, encoding="utf-8", index=False)
