# %%
import pandas as pd

# %%
file_unemploy = "unemployment_2016_2.csv"
file_wage = "LaborDataFrame(cleaned).csv"

unemploy = pd.read_csv(file_unemploy)
wage = pd.read_csv(file_wage)

# %%
unemploy.head()
# Out:
#      State                State and area Civilian labor force Dec 2016  \
# 0  Alabama                       Alabama                     2,180,260
# 1  Alabama  Anniston-Oxford-Jacksonville                        45,697
# 2  Alabama                Auburn-Opelika                        74,173
# 3  Alabama             Birmingham-Hoover                       539,602
# 4  Alabama         Daphne-Fairhope-Foley                        88,991
#
#   Unemployed Dec 2016  Percent of labor force Dec 2016
# 0             129,295                              5.9
# 1               3,060                              6.7
# 2               3,787                              5.1
# 3              29,510                              5.5
# 4               5,005                              5.6

# %%
wage.head()
# Out:
#    Unnamed: 0 State                          City  \
# 0           0    AK                     Anchorage
# 1           1    AK                     Anchorage
# 2           2    AK                     Fairbanks
# 3           3    AL  Anniston-Oxford-Jacksonville
# 4           4    AL  Anniston-Oxford-Jacksonville
#
#                                          Job Title Number of Employees  \
# 0  First-Line Supervisors of Police and Detectives                 150
# 1             Police and Sheriff's Patrol Officers                 570
# 2             Police and Sheriff's Patrol Officers                 100
# 3  First-Line Supervisors of Police and Detectives                  50
# 4                Correctional Officers and Jailers                 100
#
#   Jobs (per 1000) Mean Hourly Wage Mean Annual Wage Median Hourly Wage  \
# 0           0.871            52.64          109,490              54.35
# 1           3.228            38.75           80,600              40.83
# ...
