# %%
import pandas as pd
import numpy as np

output_data_file = "Data_Collection/Census_API/CensusDataFrame.csv"
output_loc = "Data_Collection/Census_API/sample.csv"
census_df = pd.read_csv(output_data_file)
census_df
# Out:
#       Unnamed: 0      County     State  Population  Median Age  \
# 0              0     Carroll  Arkansas     27690.0        44.4
# 1              1      Chicot  Arkansas     11189.0        43.7
# 2              2       Clark  Arkansas     22684.0        33.6
# 3              3        Clay  Arkansas     15202.0        44.0
# 4              4    Cleburne  Arkansas     25587.0        47.9
# ...          ...         ...       ...         ...         ...
# 3137        3137  Sweetwater   Wyoming     44812.0        33.8
# 3138        3138       Teton   Wyoming     22623.0        38.4
# 3139        3139       Uinta   Wyoming     20893.0        34.8
# 3140        3140    Washakie   Wyoming      8351.0        43.5
# 3141        3141      Weston   Wyoming      7175.0        43.8
#
#       Household Income  Per Capita Income  Poverty Count  Poverty Rate  \
# 0              38145.0            20888.0         4789.0     17.295052
# ...

# %%
samplecensus_df = census_df.sample(n=600)
samplecensus_df.to_csv(output_loc, encoding="utf-8", index=False)
