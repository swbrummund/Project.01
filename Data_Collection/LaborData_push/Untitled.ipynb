# %%
import pandas as pd

# %%
file = "2016_Metro_33.csv"

labor_df = pd.read_csv(file)

labor_df.head()
# Out:
#   PRIM_STATE   AREA                         AREA_NAME OCC_CODE  \
# 0         AK  11260                     Anchorage, AK  33-1012
# 1         AK  11260                     Anchorage, AK  33-3051
# 2         AK  21820                     Fairbanks, AK  33-3051
# 3         AL  11500  Anniston-Oxford-Jacksonville, AL  33-1012
# 4         AL  11500  Anniston-Oxford-Jacksonville, AL  33-3012
#
#                                          OCC_TITLE OCC_GROUP TOT_EMP EMP_PRSE  \
# 0  First-Line Supervisors of Police and Detectives  detailed     150      6.5
# 1             Police and Sheriff's Patrol Officers  detailed     570      7.7
# 2             Police and Sheriff's Patrol Officers  detailed     100      0.0
# 3  First-Line Supervisors of Police and Detectives  detailed      50     35.0
# 4                Correctional Officers and Jailers  detailed     100     40.8
#
#   JOBS_1000 LOC QUOTIENT  ... H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25  \
# ...

# %%
labor_df_clean = labor_df.drop(['AREA','OCC_CODE', 'OCC_GROUP','EMP_PRSE','LOC QUOTIENT','MEAN_PRSE','H_PCT10',
                                     'H_PCT25','H_PCT75','H_PCT90','A_PCT10','A_PCT25','A_PCT75','A_PCT90',
                                      'ANNUAL','HOURLY'], axis = 1)

# %%
labor_df_clean = labor_df_clean.rename(columns={"PRIM_STATE":"State","AREA_NAME":"City","OCC_TITLE":"Job Title",
                                         "TOT_EMP":"Number of Employees", "JOBS_1000":"Jobs (per 1000)",
                                         "H_MEDIAN":"Median Hourly Wage","A_MEDIAN":"Annual Median Wage",
                                         "H_MEAN":"Mean Hourly Wage","A_MEAN":"Mean Annual Wage"})

# %%
labor_df_clean.head()
# Out:
#   State                              City  \
# 0    AK                     Anchorage, AK
# 1    AK                     Anchorage, AK
# 2    AK                     Fairbanks, AK
# 3    AL  Anniston-Oxford-Jacksonville, AL
# 4    AL  Anniston-Oxford-Jacksonville, AL
#
#                                          Job Title Number of Employees  \
# 0  First-Line Supervisors of Police and Detectives                 150
# 1             Police and Sheriff's Patrol Officers                 570
# 2             Police and Sheriff's Patrol Officers                 100
# 3  First-Line Supervisors of Police and Detectives                  50
# 4                Correctional Officers and Jailers                 100
#
#   Jobs (per 1000) Mean Hourly Wage Mean Annual Wage Median Hourly Wage  \
# 0           0.871            52.64          109,490              54.35
# 1           3.228            38.75           80,600              40.83
# ...

# %%
labor_df["HOURLY"].value_counts()
# Out:
# Series([], Name: HOURLY, dtype: int64)

# %%
new = labor_df_clean["City"].str.split(",", n = 1, expand = True)
labor_df_clean["City"] = new[0]
labor_df_clean['State'] = new[1]
new.head()
# Out:
#                               0    1
# 0                     Anchorage   AK
# 1                     Anchorage   AK
# 2                     Fairbanks   AK
# 3  Anniston-Oxford-Jacksonville   AL
# 4  Anniston-Oxford-Jacksonville   AL

# %%
labor_df_clean.head()
# Out:
#   State                          City  \
# 0    AK                     Anchorage
# 1    AK                     Anchorage
# 2    AK                     Fairbanks
# 3    AL  Anniston-Oxford-Jacksonville
# 4    AL  Anniston-Oxford-Jacksonville
#
#                                          Job Title Number of Employees  \
# 0  First-Line Supervisors of Police and Detectives                 150
# 1             Police and Sheriff's Patrol Officers                 570
# 2             Police and Sheriff's Patrol Officers                 100
# 3  First-Line Supervisors of Police and Detectives                  50
# 4                Correctional Officers and Jailers                 100
#
#   Jobs (per 1000) Mean Hourly Wage Mean Annual Wage Median Hourly Wage  \
# 0           0.871            52.64          109,490              54.35
# 1           3.228            38.75           80,600              40.83
# 2           2.783            35.90           74,660              35.32
# ...

# %%
labor_df_clean.to_csv("LaborDataFrame(cleaned).csv")
